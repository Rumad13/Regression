# %% [markdown]
# # EDA

# %%
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
data=pd.read_csv("Milk.csv")
data.head(5)
# Out:
#    Year  Milk Production
# 0  1991             1620
# 1  1992             2110
# 2  1993             2466
# 3  1994             2800
# 4  1995             3266

# %%
plt.figure(figsize=(8,6))
sns.regplot(x="Year",y="Milk Production",data=data,color="green")
plt.xlabel("Year")
plt.ylabel("Milk Production")
# Out:
# Text(0, 0.5, 'Milk Production')

# %% [markdown]
# # Model Building : Linear Regression

# %%
ss=StandardScaler()
lr=LinearRegression()

# %%
x=data[["Year"]]
y=data["Milk Production"]
x=ss.fit_transform(x)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# # Train Model

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Testing Model

# %%
y_pred=lr.predict(x_test)

# %%
Table = pd.DataFrame({
    'Actual Values': y_test,
    'Predicted Values': y_pred,
    "Residual" : y_test-y_pred
})
print(Table)
# Out:
#     Actual Values  Predicted Values     Residual
# 33          11655      11470.088420   184.911580
# 36          14304      11797.085301  2506.914699
# 4            3266       2641.172632   624.827368
# 13           5609       5584.144562    24.855438
# 30          10152      10489.097777  -337.097777
# 26           8200       9181.110253  -981.110253
# 6            3955       3295.166394   659.833606
# 27           8733       9508.107134  -775.107134

# %% [markdown]
# # Model Evolution

# %%
from sklearn.metrics import r2_score
r2=r2_score(y_test,y_pred)
print("Accuracy :",r2*100)
# Out:
# Accuracy : 91.3810544934245
